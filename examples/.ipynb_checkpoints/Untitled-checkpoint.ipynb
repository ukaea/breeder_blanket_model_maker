# %%
import sys
sys.dont_write_bytecode = True
from collections import OrderedDict
import multiprocessing
import math
from breeder_blanket_model_maker import *
from breeder_blanket_model_maker.rewrite_cad_files import *
from breeder_blanket_model_maker.serpent_tools import *
from breeder_blanket_model_maker.make_serpent_input_file import *

from neutronics_material_maker.nmm import *
from neutronics_material_maker.examples import *


def define_blanket_geometry_parmeters(blanket_type,input_files,output_directory,poloidal_lithium_lead_in_mm = 35.4):

    poloidal_lithium_lead_in_mm = float(poloidal_lithium_lead_in_mm)
    smd = 274. * 1000000.  # units Pa

    cooling_plates_channel_poloidal_mm = 3.0
    cooling_plates_channel_radial_mm = 3.0
    cooling_plates_channel_toroidal_mm = 6.0
    first_wall_channel_radial_mm = 10.0
    first_wall_channel_poloidal_mm = 15.0
    first_wall_channel_pitch_mm = 5.2

    pressure_coolant = 10. * 1000000.  # in units Pa

    first_walls_thickness = (first_wall_channel_radial_mm/1000) + math.sqrt((pressure_coolant * (poloidal_lithium_lead_in_mm/1000) * (poloidal_lithium_lead_in_mm/1000) ) / (4. * smd))  # units in m
    first_walls_thickness_mm = first_walls_thickness *1000

    poloidal_cooling_plate_mm = (pressure_coolant * (poloidal_lithium_lead_in_mm)) / (1.1 * smd)

    poloidal_cooling_plate_mm = max(poloidal_cooling_plate_mm, 0.002*1000) + cooling_plates_channel_poloidal_mm

    cooling_channel_offset_from_first_wall = (first_walls_thickness_mm - first_wall_channel_radial_mm) / 2.0

    if cooling_channel_offset_from_first_wall < 1.0:
        raise ValueError('first wall is too thin at ',cooling_channel_offset_from_first_wall, 'mm')

    poloidal_segmentations_ordered_dict=OrderedDict()
    poloidal_segmentations_ordered_dict['lithium_lead']=poloidal_lithium_lead_in_mm
    poloidal_segmentations_ordered_dict['cooling_plate_homogenised']=poloidal_cooling_plate_mm

    back_plates_thicknesses_ordered_dict=OrderedDict()  #these are special ordereddict types required in python 2.7 but in python 3.6 onwards dictionaries are ordered by default, sadly freecad is not yet avaialbe in python 3
    back_plates_thicknesses_ordered_dict['back_plate_1']=30
    back_plates_thicknesses_ordered_dict['back_helium']=50
    back_plates_thicknesses_ordered_dict['back_plate_2']=30
    back_plates_thicknesses_ordered_dict['back_lithium_lead']=25
    back_plates_thicknesses_ordered_dict['back_plate_3']=10

    first_wall_channel_poloidal_segmentations_dict=OrderedDict()
    first_wall_channel_poloidal_segmentations_dict['first_wall_material']=first_wall_channel_poloidal_mm
    first_wall_channel_poloidal_segmentations_dict['first_wall_coolant']=first_wall_channel_pitch_mm


    list_of_compressed_arguments=[]
    for module in input_files:

        blanket_geometry_parameters =  {

            'blanket_type' : blanket_type,
            'plasma_filename' :'/home/jshim/Eurofusion_baseline_2016/envelopes/plasma.step',
            'envelope_filename' : module,
            'output_folder' : output_directory,
            'output_files':['step','stl'],
            'first_wall_poloidal_fillet_radius' : 50,
            'armour_thickness' : 2,
            'first_wall_thickness' : first_walls_thickness_mm,
            'end_cap_thickness' : 25,
            'back_plates_thicknesses' : back_plates_thicknesses_ordered_dict,
            'poloidal_segmentations' : poloidal_segmentations_ordered_dict,

        }

        if module == input_files[-1]:
            blanket_geometry_parameters.update({
                #The following three arguments are optional, if included the model will include cooling channels on the first wall
                'cooling_channel_offset_from_first_wall': cooling_channel_offset_from_first_wall,
                'first_wall_channel_radial_mm': first_wall_channel_radial_mm,
                'first_wall_channel_poloidal_segmentations': first_wall_channel_poloidal_segmentations_dict,  # 13.5,4.5

                # #The following two arguments are optional, if included the model will include a slice of blanket and cooling channels in the cooling plate
                'cooling_plates_channel_poloidal_mm':cooling_plates_channel_poloidal_mm,
                'cooling_plates_channel_radial_mm':cooling_plates_channel_radial_mm,

                'output_files':['step','stl','umesh'],
                })



        list_of_compressed_arguments.append(blanket_geometry_parameters)

    return list_of_compressed_arguments

def define_neutronics_materials(enrichment_fraction):

    mat_lithium_lead =Compound('Pb84.2Li15.8',
                              density_atoms_per_barn_per_cm=3.2720171E-2,
                              enriched_isotopes=[Isotope('Li',6,abundance=enrichment_fraction),
                                                 Isotope('Li',7,abundance=1.0-enrichment_fraction)])

    material_dictionary = {  'armour': mat_Tungsten,
                             'lithium_lead': mat_lithium_lead,
                             'back_plate_1': mat_Eurofer,
                             'back_plate_2': mat_Eurofer,
                             'back_plate_3': mat_Eurofer,
                             'back_lithium_lead': mat_lithium_lead,
                             'back_helium': mat_He_coolant_back_plate,
                             'cooling_plate_homogenised': mat_cooling_plates_homogenised,
                             'end_caps_homogenised': mat_end_caps_homogenised,
                             'first_wall_homogenised': mat_first_wall_homogenised,
                             'plasma': mat_DT_plasma,
                             'central_solenoid': mat_central_solenoid_m25,
                             'divertor_1st_layer': mat_divertor_layer_1_m15, 
                             'divertor_2nd_layer': mat_divertor_layer_2_m74, 
                             'divertor_3rd_layer': mat_divertor_layer_3_m15,
                             'divertor_4th_layer': mat_divertor_layer_4_m75,
                             'manifolder': mat_VV_Body_m60 ,
                             'ports': mat_TF_Casing_m50,
                             #'shell': , # outer shell ignored
                             'shield': mat_TF_Casing_m50,
                             'tf_case': mat_TF_Casing_m50,
                             'tf_coils': mat_TF_Magnet_m25,
                             'vacuum_1st_layer': mat_VV_Shell_m50,
                             'vacuum_2nd_layer': mat_VV_Body_m60,
                             'vacuum_3rd_layer': mat_VV_Shell_m50,
                             'vaccum_vessel_shield': mat_ShieldPort_m60,
                             'blanket_support':mat_Eurofer,

                             'first_wall_coolant':mat_He_in_first_walls,
                             'first_wall_material':mat_He_in_first_walls,

                             'slice_lithium_lead':mat_lithium_lead,
                             'slice_armour':mat_Tungsten,
                             'slice_first_wall_material':mat_Eurofer,
                             'slice_first_wall_homogenised':mat_first_wall_homogenised, #ignore
                             'slice_first_wall_coolant':mat_He_in_first_walls,
                             'slice_cooling_plate_material':mat_cooling_plates_homogenised,
                             'slice_cooling_plate_coolant':mat_He_in_coolant_plates,
                             'slice_back_plate_1':mat_Eurofer,
                             'slice_back_helium':mat_He_coolant_back_plate,
                             'slice_back_plate_2':mat_Eurofer,
                             'slice_back_lithium_lead':mat_lithium_lead,
                             'slice_back_plate_3':mat_Eurofer,
                          }
    return material_dictionary

def define_neutronics_model_parmeters(list_detailed_modules_parts,material_dictionary,output_directory,nps=1e7,**kwargs):

    neutronics_parameters= { 'output_folder':output_directory,
                             'parts':list_detailed_modules_parts,
                             'include_umesh':True,
                             'output_folder_stl':os.path.join(output_directory,'stl'),
                             'material_dictionary':material_dictionary,
                             'plot_serpent_geometry':False,
                             'nps':nps,
                             'tallies':[{'name':'tbr',
                                            'bodies':['lithium_lead'],
                                            'mt_number':-55,
                                            'particle_type':'n'},
                                        {'name':'neutron_heating',
                                            'bodies':['armour','lithium_lead','back_plate_1','back_plate_2','back_plate_3','back_lithium_lead','back_helium','cooling_plate_homogenised','end_caps_homogenised','first_wall_homogenised',],
                                            'mt_number':-4,
                                            'particle_type':'n'},
                                        {'name':'photon_heating',
                                            'bodies':['armour','lithium_lead','back_plate_1','back_plate_2','back_plate_3','back_lithium_lead','back_helium','cooling_plate_homogenised','end_caps_homogenised','first_wall_homogenised',],
                                            'mt_number':-26,
                                            'particle_type':'p'},                                            
                                       ]
                             }

    return neutronics_parameters

# %%
output_directory='/home/jshim/detailed_HCLL'
list_of_geometry_parameters = define_blanket_geometry_parmeters(blanket_type ='HCLL',
                                                                input_files= ['/home/jshim/Eurofusion_baseline_2016/envelopes/mod' + str(x) + '.step' for x in range(1, 2)],#27,
                                                                output_directory = output_directory,
                                                                poloidal_lithium_lead_in_mm =80.0)
list_of_geometry_parameters
# Out:
# [{'armour_thickness': 2,
#   'back_plates_thicknesses': OrderedDict([('back_plate_1', 30),
#                ('back_helium', 50),
#                ('back_plate_2', 30),
#                ('back_lithium_lead', 25),
#                ('back_plate_3', 10)]),
#   'blanket_type': 'HCLL',
#   'cooling_channel_offset_from_first_wall': 3.8208035995043517,
#   'cooling_plates_channel_poloidal_mm': 3.0,
#   'cooling_plates_channel_radial_mm': 3.0,
#   'end_cap_thickness': 25,
#   'envelope_filename': '/home/jshim/Eurofusion_baseline_2016/envelopes/mod1.step',
#   'first_wall_channel_poloidal_segmentations': OrderedDict([('first_wall_material',
#                 15.0),
#                ('first_wall_coolant', 5.2)]),
#   'first_wall_channel_radial_mm': 10.0,
#   'first_wall_poloidal_fillet_radius': 50,
#   'first_wall_thickness': 17.641607199008703,
#   'output_files': ['step', 'stl', 'umesh'],
#   'output_folder': '/home/jshim/detailed_HCLL',
#   'plasma_filename': '/home/jshim/Eurofusion_baseline_2016/envelopes/plasma.step',
#   'poloidal_segmentations': OrderedDict([('lithium_lead', 80.0),
#                ('cooling_plate_homogenised', 5.6542800265428)])}]

# %%
reload(breeder_blanket_model_maker)
reload(breeder_blanket_model_maker.rewrite_cad_files)
reload(breeder_blanket_model_maker.serpent_tools)
reload(breeder_blanket_model_maker.make_serpent_input_file)
# Out:
# <module 'breeder_blanket_model_maker.make_serpent_input_file' from '/usr/local/lib/python2.7/dist-packages/breeder_blanket_model_maker-0.3-py2.7.egg/breeder_blanket_model_maker/make_serpent_input_file.pyc'>

# %%
list_of_detailed_modules_parts = detailed_module(list_of_geometry_parameters)
# Out:
# Creating detailed HCLL
# 'read_in_envelope_file'  11.69 ms
# 'find_envelope_back_face'  1516.51 ms
# 'find_envelope_front_face'  6.80 ms
# 'find_front_face_midpoint'  0.21 ms
# 'envelope_front_face_id'  6.23 ms
# 'find_envelope_back_face_id'  1496.92 ms
# 'find_front_face_polodial_edges_to_fillet'  0.18 ms
# 'find_front_face_torodial_edges_to_fillet'  0.05 ms
# 'filleted_envelope'  8.04 ms
# 'find_envelope_back_face'  2296.13 ms
# 'find_envelope_front_face'  11.12 ms
# 'envelope_front_face_id'  12.68 ms
# 'find_end_cap_faces'  0.19 ms
# 'chop_off_first_wall_armour'  202.68 ms
# 'find_envelope_back_face'  2273.56 ms
# 'find_envelope_front_face'  7.71 ms
# 'find_end_cap_faces'  0.20 ms
# 'find_envelope_back_face'  2268.56 ms
# 'find_envelope_front_face'  7.56 ms
# 'chop_off_first_wall'  62.73 ms
# 'find_envelope_back_face'  2267.38 ms
# 'find_envelope_front_face'  7.64 ms
# 'find_front_face_midpoint'  0.24 ms
# 'chop_off_first_wall'  72.98 ms
# 'chop_off_first_wall'  69.06 ms
# 'convert_distances_into_cumlative_distances'  1.92 ms
# 'exstrude_and_cut_solids_up_to_change_in_shape'  12497.90 ms
# 'exstrude_and_cut_solids_up_to_change_in_shape'  11921.19 ms
# 'chop_up_poloidally'  24424.27 ms
# 'chop_of_end_caps'  104.13 ms
# 'find_envelope_back_face'  2434.22 ms
# 'chop_off_back_plates'  443.17 ms
# 'convert_distances_into_cumlative_distances'  0.78 ms
# 'exstrude_and_cut_solids'  1632.87 ms
# 'exstrude_and_cut_solids'  1414.44 ms
# 'chop_up_poloidally'  3050.64 ms
# 'convert_distances_into_cumlative_distances'  0.96 ms
# 'exstrude_and_cut_solids'  8.21 ms
# 'chop_up_poloidally'  9.81 ms
# 'common_and_uncommon_solids_with_envelope'  224.00 ms
# 'common_and_uncommon_solids_with_envelope'  44.71 ms
# 'common_and_uncommon_solids_with_envelope'  43.38 ms
# 'common_and_uncommon_solids_with_envelope'  1227.85 ms
# 'common_and_uncommon_solids_with_envelope'  1070.93 ms
# 'common_and_uncommon_solids_with_envelope'  14.83 ms
# 'common_and_uncommon_solids_with_envelope'  13.59 ms
# 'common_and_uncommon_solids_with_envelope'  13.04 ms
# 'common_and_uncommon_solids_with_envelope'  13.11 ms
# 'common_and_uncommon_solids_with_envelope'  12.92 ms
# 'common_and_uncommon_solids_with_envelope'  157.64 ms
# 'find_largest_face'  0.60 ms
# 'chop_top_and_bottom_from_cooling_plate'  871.50 ms
# 'find_largest_face'  0.80 ms
# 'find_largest_face'  0.61 ms
# 'find_envelope_back_face'  1227.57 ms
# 'find_envelope_back_face_id'  1216.56 ms
# ('cooling channel formation cut_solid.Volume', 15819.99102804347)
# ('cooling channel formation cut_solid.Volume', 62431.10591371675)
# ('cooling channel formation cut_solid.Volume', 15395.561922648601)
# ('cooling channel formation cut_solid.Volume', 70515.0033407363)
# ('cooling channel formation cut_solid.Volume', 14793.194401950575)
# ('cooling channel formation cut_solid.Volume', 76995.56030139758)
# ('cooling channel formation cut_solid.Volume', 14080.140710901818)
# ('cooling channel formation cut_solid.Volume', 82116.50834251803)
# ('cooling channel formation cut_solid.Volume', 13292.028736520995)
# ('cooling channel formation cut_solid.Volume', 85736.29071805452)
# ('cooling channel formation cut_solid.Volume', 12428.858478862458)
# ('cooling channel formation cut_solid.Volume', 87704.79086141591)
# ('cooling channel formation cut_solid.Volume', 11490.629937900696)
# ('cooling channel formation cut_solid.Volume', 87871.89220628113)
# ('cooling channel formation cut_solid.Volume', 10477.343113684212)
# ('cooling channel formation cut_solid.Volume', 86087.47818593874)
# ('cooling channel formation cut_solid.Volume', 9388.998006140086)
# ('cooling channel formation cut_solid.Volume', 82201.43223384692)
# ('cooling channel formation cut_solid.Volume', 8225.594615382186)
# ('cooling channel formation cut_solid.Volume', 76063.63778340374)
# ('cooling channel formation cut_solid.Volume', 6987.132941331816)
# ('cooling channel formation cut_solid.Volume', 67523.97826817317)
# ('cooling channel formation cut_solid.Volume', 5673.612983960527)
# ('cooling channel formation cut_solid.Volume', 56432.33712152588)
# ('cooling channel formation cut_solid.Volume', 4285.034743359816)
# ('cooling channel formation cut_solid.Volume', 42638.597776917)
# ('cooling channel formation cut_solid.Volume', 2821.3982194633627)
# error the end of the cooling channels has been reached
# 'add_cooling_pipes_to_div'  6833.45 ms
# 'make_cylinder_slice'  0.29 ms
# 'make_cylinder_slice'  0.26 ms
# 'make_cylinder_slice'  0.20 ms
# 'make_cylinder_slice'  0.27 ms
# 'make_cylinder_slice'  0.62 ms
# 'make_cylinder_slice'  1.35 ms
# 'make_cylinder_slice'  13.83 ms
# 'make_cylinder_slice'  0.21 ms
# 'make_cylinder_slice'  0.25 ms
# 'make_cylinder_slice'  0.29 ms
# 'make_cylinder_slice'  1.11 ms
# 'make_cylinder_slice'  0.27 ms
# 'save_components_as_step'  15356.83 ms
# 'save_components_as_stl'  7241.95 ms
# defaultdict(<type 'dict'>, {'slice_first_wall_homogenised': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/slice_first_wall_homogenised_mod1_1.stl'], 'part': [<Shape object at 0xaf7a000>], 'step_filename': '/home/jshim/detailed_HCLL/step/slice_first_wall_homogenised_mod1.step'}, 'back_lithium_lead': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_2.stl'], 'part': [<Shape object at 0xbe0f190>], 'step_filename': '/home/jshim/detailed_HCLL/step/back_lithium_lead_mod1.step'}, 'armour': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/armour_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/armour_mod1_2.stl'], 'part': [<Shape object at 0xa5dc140>], 'step_filename': '/home/jshim/detailed_HCLL/step/armour_mod1.step'}, 'slice_back_plate_2': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/slice_back_plate_2_mod1_1.stl'], 'part': [<Shape object at 0xb15e0a0>], 'step_filename': '/home/jshim/detailed_HCLL/step/slice_back_plate_2_mod1.step'}, 'slice_back_plate_3': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/slice_back_plate_3_mod1_1.stl'], 'part': [<Shape object at 0xb0871f0>], 'step_filename': '/home/jshim/detailed_HCLL/step/slice_back_plate_3_mod1.step'}, 'slice_back_plate_1': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/slice_back_plate_1_mod1_1.stl'], 'part': [<Shape object at 0x9f86d80>], 'step_filename': '/home/jshim/detailed_HCLL/step/slice_back_plate_1_mod1.step'}, 'back_helium': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/back_helium_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/back_helium_mod1_2.stl'], 'part': [<Shape object at 0xae24f80>], 'step_filename': '/home/jshim/detailed_HCLL/step/back_helium_mod1.step'}, 'first_wall_material': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_2.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_3.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_4.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_5.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_6.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_7.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_8.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_9.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_10.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_11.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_12.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_13.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_14.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_15.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_16.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_17.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_18.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_19.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_20.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_21.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_22.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_23.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_24.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_25.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_26.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_27.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_28.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_29.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_30.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_31.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_32.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_33.stl', '/home/jshim/detailed_HCLL/stl/first_wall_material_mod1_34.stl', '/home/jshim/detailed_H ...
# {'stl_filename': ['/home/jshim/detailed_HCLL/stl/slice_envelope_mod1_1.stl'], 'part': [<Shape object at 0xa649bb0>], 'step_filename': '/home/jshim/detailed_HCLL/step/slice_envelope_mod1.step'}
# 'mccad_convert_solid'  152.22 ms
# 'save_components_as_umesh'  154.04 ms

# %%
filepath=list_of_detailed_modules_parts['slice_envelope']['step_filename']
path = os.path.dirname(filepath)

# %%
os.system('cd /home/jshim/detailed_HCLL/step/')

os.system('pwd')
os.chdir('/home/jshim/detailed_HCLL/step/')
a=os.getcwd()
print('a',a)
os.system('McCad -d slice_envelope_mod1.step -1')
os.system('ls')
# Out:
# ('a', '/home/jshim/detailed_HCLL/step')
# 0

# %%
os.path.dirname('/home/jshim/detailed_HCLL/step/slice_envelope_mod1.step')
# Out:
# '/home/jshim/detailed_HCLL/step'

# %%
extra_parts = read_in_step_files_and_save_as_seperate_stl_files(read_folder='/home/jshim/Eurofusion_baseline_2016/reactor_step_files',
                                                                write_folder=os.path.join(output_directory,'stl'),
                                                                ignore_files=['shell.stp'])
# Out:
# ('error making folder', '/home/jshim/detailed_HCLL/stl')
# ('read_folder', '/home/jshim/Eurofusion_baseline_2016/reactor_step_files')
# ['shield.stp', 'vacuum_1st_layer.stp', 'divertor_4th_layer.stp', 'divertor_3rd_layer.stp', 'divertor_2nd_layer.stp', 'vaccum_vessel_shield.stp', 'plasma.stp', 'divertor_1st_layer.stp', 'blanket_support.stp', 'central_solenoid.stp', 'vacuum_2nd_layer.stp', 'manifolder.stp', 'ports.stp', 'shell.stp', 'vacuum_3rd_layer.stp', 'tf_coils.stp', 'tf_case.stp']
# shield.stp
# vacuum_1st_layer.stp
# divertor_4th_layer.stp
# divertor_3rd_layer.stp
# divertor_2nd_layer.stp
# vaccum_vessel_shield.stp
# plasma.stp
# divertor_1st_layer.stp
# blanket_support.stp
# central_solenoid.stp
# vacuum_2nd_layer.stp
# manifolder.stp
# ports.stp
# vacuum_3rd_layer.stp
# tf_coils.stp
# tf_case.stp

# %%
neutronics_parameters['output_folder']
# Out:
# '/home/jshim/detailed_HCLL'

# %%
material_dictionary=define_neutronics_materials(enrichment_fraction=0.8)

# %%
directory_path_to_serpent_output,number_of_stl_parts= make_serpent_stl_based_input_file(neutronics_parameters)
# Out:
# <type 'list'>
# (defaultdict(<type 'dict'>, {'slice_first_wall_homogenised': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/slice_first_wall_homogenised_mod1_1.stl'], 'part': [<Shape object at 0x846d0c0>], 'step_filename': '/home/jshim/detailed_HCLL/step/slice_first_wall_homogenised_mod1.step'}, 'tf_case': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_case_1.stl', '/home/jshim/detailed_HCLL/stl/tf_case_2.stl', '/home/jshim/detailed_HCLL/stl/tf_case_3.stl', '/home/jshim/detailed_HCLL/stl/tf_case_4.stl', '/home/jshim/detailed_HCLL/stl/tf_case_5.stl', '/home/jshim/detailed_HCLL/stl/tf_case_6.stl', '/home/jshim/detailed_HCLL/stl/tf_case_7.stl', '/home/jshim/detailed_HCLL/stl/tf_case_8.stl', '/home/jshim/detailed_HCLL/stl/tf_case_9.stl', '/home/jshim/detailed_HCLL/stl/tf_case_10.stl', '/home/jshim/detailed_HCLL/stl/tf_case_11.stl', '/home/jshim/detailed_HCLL/stl/tf_case_12.stl', '/home/jshim/detailed_HCLL/stl/tf_case_13.stl', '/home/jshim/detailed_HCLL/stl/tf_case_14.stl', '/home/jshim/detailed_HCLL/stl/tf_case_15.stl', '/home/jshim/detailed_HCLL/stl/tf_case_16.stl', '/home/jshim/detailed_HCLL/stl/tf_case_17.stl', '/home/jshim/detailed_HCLL/stl/tf_case_18.stl', '/home/jshim/detailed_HCLL/stl/tf_case_19.stl', '/home/jshim/detailed_HCLL/stl/tf_case_20.stl', '/home/jshim/detailed_HCLL/stl/tf_case_21.stl', '/home/jshim/detailed_HCLL/stl/tf_case_22.stl', '/home/jshim/detailed_HCLL/stl/tf_case_23.stl', '/home/jshim/detailed_HCLL/stl/tf_case_24.stl', '/home/jshim/detailed_HCLL/stl/tf_case_25.stl', '/home/jshim/detailed_HCLL/stl/tf_case_26.stl', '/home/jshim/detailed_HCLL/stl/tf_case_27.stl', '/home/jshim/detailed_HCLL/stl/tf_case_28.stl', '/home/jshim/detailed_HCLL/stl/tf_case_29.stl', '/home/jshim/detailed_HCLL/stl/tf_case_30.stl', '/home/jshim/detailed_HCLL/stl/tf_case_31.stl', '/home/jshim/detailed_HCLL/stl/tf_case_32.stl'], 'part': <Shape object at 0x8ffeab0>}, 'central_solenoid': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/central_solenoid_1.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_2.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_3.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_4.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_5.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_6.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_7.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_8.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_9.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_10.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_11.stl'], 'part': <Shape object at 0x8b4c280>}, 'back_lithium_lead': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_2.stl'], 'part': [<Shape object at 0x83f7210>], 'step_filename': '/home/jshim/detailed_HCLL/step/back_lithium_lead_mod1.step'}, 'shield': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/shield_1.stl', '/home/jshim/detailed_HCLL/stl/shield_2.stl', '/home/jshim/detailed_HCLL/stl/shield_3.stl', '/home/jshim/detailed_HCLL/stl/shield_4.stl', '/home/jshim/detailed_HCLL/stl/shield_5.stl', '/home/jshim/detailed_HCLL/stl/shield_6.stl', '/home/jshim/detailed_HCLL/stl/shield_7.stl', '/home/jshim/detailed_HCLL/stl/shield_8.stl', '/home/jshim/detailed_HCLL/stl/shield_9.stl', '/home/jshim/detailed_HCLL/stl/shield_10.stl', '/home/jshim/detailed_HCLL/stl/shield_11.stl', '/home/jshim/detailed_HCLL/stl/shield_12.stl', '/home/jshim/detailed_HCLL/stl/shield_13.stl', '/home/jshim/detailed_HCLL/stl/shield_14.stl'], 'part': <Shape object at 0x85ade90>}, 'armour': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/armour_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/armour_mod1_2.stl'], 'part': [<Shape object at 0x843a010>], 'step_filename': '/home/jshim/detailed_HCLL/step/armour_mod1.step'}, 'tf_coils': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_coils_1.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_2.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_3.stl', '/home/jshim/de ...
# (defaultdict(<type 'dict'>, {'slice_first_wall_homogenised': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/slice_first_wall_homogenised_mod1_1.stl'], 'part': [<Shape object at 0x846d0c0>], 'step_filename': '/home/jshim/detailed_HCLL/step/slice_first_wall_homogenised_mod1.step'}, 'tf_case': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_case_1.stl', '/home/jshim/detailed_HCLL/stl/tf_case_2.stl', '/home/jshim/detailed_HCLL/stl/tf_case_3.stl', '/home/jshim/detailed_HCLL/stl/tf_case_4.stl', '/home/jshim/detailed_HCLL/stl/tf_case_5.stl', '/home/jshim/detailed_HCLL/stl/tf_case_6.stl', '/home/jshim/detailed_HCLL/stl/tf_case_7.stl', '/home/jshim/detailed_HCLL/stl/tf_case_8.stl', '/home/jshim/detailed_HCLL/stl/tf_case_9.stl', '/home/jshim/detailed_HCLL/stl/tf_case_10.stl', '/home/jshim/detailed_HCLL/stl/tf_case_11.stl', '/home/jshim/detailed_HCLL/stl/tf_case_12.stl', '/home/jshim/detailed_HCLL/stl/tf_case_13.stl', '/home/jshim/detailed_HCLL/stl/tf_case_14.stl', '/home/jshim/detailed_HCLL/stl/tf_case_15.stl', '/home/jshim/detailed_HCLL/stl/tf_case_16.stl', '/home/jshim/detailed_HCLL/stl/tf_case_17.stl', '/home/jshim/detailed_HCLL/stl/tf_case_18.stl', '/home/jshim/detailed_HCLL/stl/tf_case_19.stl', '/home/jshim/detailed_HCLL/stl/tf_case_20.stl', '/home/jshim/detailed_HCLL/stl/tf_case_21.stl', '/home/jshim/detailed_HCLL/stl/tf_case_22.stl', '/home/jshim/detailed_HCLL/stl/tf_case_23.stl', '/home/jshim/detailed_HCLL/stl/tf_case_24.stl', '/home/jshim/detailed_HCLL/stl/tf_case_25.stl', '/home/jshim/detailed_HCLL/stl/tf_case_26.stl', '/home/jshim/detailed_HCLL/stl/tf_case_27.stl', '/home/jshim/detailed_HCLL/stl/tf_case_28.stl', '/home/jshim/detailed_HCLL/stl/tf_case_29.stl', '/home/jshim/detailed_HCLL/stl/tf_case_30.stl', '/home/jshim/detailed_HCLL/stl/tf_case_31.stl', '/home/jshim/detailed_HCLL/stl/tf_case_32.stl'], 'part': <Shape object at 0x8ffeab0>}, 'central_solenoid': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/central_solenoid_1.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_2.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_3.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_4.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_5.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_6.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_7.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_8.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_9.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_10.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_11.stl'], 'part': <Shape object at 0x8b4c280>}, 'back_lithium_lead': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_2.stl'], 'part': [<Shape object at 0x83f7210>], 'step_filename': '/home/jshim/detailed_HCLL/step/back_lithium_lead_mod1.step'}, 'shield': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/shield_1.stl', '/home/jshim/detailed_HCLL/stl/shield_2.stl', '/home/jshim/detailed_HCLL/stl/shield_3.stl', '/home/jshim/detailed_HCLL/stl/shield_4.stl', '/home/jshim/detailed_HCLL/stl/shield_5.stl', '/home/jshim/detailed_HCLL/stl/shield_6.stl', '/home/jshim/detailed_HCLL/stl/shield_7.stl', '/home/jshim/detailed_HCLL/stl/shield_8.stl', '/home/jshim/detailed_HCLL/stl/shield_9.stl', '/home/jshim/detailed_HCLL/stl/shield_10.stl', '/home/jshim/detailed_HCLL/stl/shield_11.stl', '/home/jshim/detailed_HCLL/stl/shield_12.stl', '/home/jshim/detailed_HCLL/stl/shield_13.stl', '/home/jshim/detailed_HCLL/stl/shield_14.stl'], 'part': <Shape object at 0x85ade90>}, 'armour': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/armour_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/armour_mod1_2.stl'], 'part': [<Shape object at 0x843a010>], 'step_filename': '/home/jshim/detailed_HCLL/step/armour_mod1.step'}, 'tf_coils': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_coils_1.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_2.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_3.stl', '/home/jshim/de ...
# (defaultdict(<type 'dict'>, {'slice_first_wall_homogenised': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/slice_first_wall_homogenised_mod1_1.stl'], 'part': [<Shape object at 0x846d0c0>], 'step_filename': '/home/jshim/detailed_HCLL/step/slice_first_wall_homogenised_mod1.step'}, 'tf_case': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_case_1.stl', '/home/jshim/detailed_HCLL/stl/tf_case_2.stl', '/home/jshim/detailed_HCLL/stl/tf_case_3.stl', '/home/jshim/detailed_HCLL/stl/tf_case_4.stl', '/home/jshim/detailed_HCLL/stl/tf_case_5.stl', '/home/jshim/detailed_HCLL/stl/tf_case_6.stl', '/home/jshim/detailed_HCLL/stl/tf_case_7.stl', '/home/jshim/detailed_HCLL/stl/tf_case_8.stl', '/home/jshim/detailed_HCLL/stl/tf_case_9.stl', '/home/jshim/detailed_HCLL/stl/tf_case_10.stl', '/home/jshim/detailed_HCLL/stl/tf_case_11.stl', '/home/jshim/detailed_HCLL/stl/tf_case_12.stl', '/home/jshim/detailed_HCLL/stl/tf_case_13.stl', '/home/jshim/detailed_HCLL/stl/tf_case_14.stl', '/home/jshim/detailed_HCLL/stl/tf_case_15.stl', '/home/jshim/detailed_HCLL/stl/tf_case_16.stl', '/home/jshim/detailed_HCLL/stl/tf_case_17.stl', '/home/jshim/detailed_HCLL/stl/tf_case_18.stl', '/home/jshim/detailed_HCLL/stl/tf_case_19.stl', '/home/jshim/detailed_HCLL/stl/tf_case_20.stl', '/home/jshim/detailed_HCLL/stl/tf_case_21.stl', '/home/jshim/detailed_HCLL/stl/tf_case_22.stl', '/home/jshim/detailed_HCLL/stl/tf_case_23.stl', '/home/jshim/detailed_HCLL/stl/tf_case_24.stl', '/home/jshim/detailed_HCLL/stl/tf_case_25.stl', '/home/jshim/detailed_HCLL/stl/tf_case_26.stl', '/home/jshim/detailed_HCLL/stl/tf_case_27.stl', '/home/jshim/detailed_HCLL/stl/tf_case_28.stl', '/home/jshim/detailed_HCLL/stl/tf_case_29.stl', '/home/jshim/detailed_HCLL/stl/tf_case_30.stl', '/home/jshim/detailed_HCLL/stl/tf_case_31.stl', '/home/jshim/detailed_HCLL/stl/tf_case_32.stl'], 'part': <Shape object at 0x8ffeab0>}, 'central_solenoid': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/central_solenoid_1.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_2.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_3.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_4.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_5.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_6.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_7.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_8.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_9.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_10.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_11.stl'], 'part': <Shape object at 0x8b4c280>}, 'back_lithium_lead': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_2.stl'], 'part': [<Shape object at 0x83f7210>], 'step_filename': '/home/jshim/detailed_HCLL/step/back_lithium_lead_mod1.step'}, 'shield': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/shield_1.stl', '/home/jshim/detailed_HCLL/stl/shield_2.stl', '/home/jshim/detailed_HCLL/stl/shield_3.stl', '/home/jshim/detailed_HCLL/stl/shield_4.stl', '/home/jshim/detailed_HCLL/stl/shield_5.stl', '/home/jshim/detailed_HCLL/stl/shield_6.stl', '/home/jshim/detailed_HCLL/stl/shield_7.stl', '/home/jshim/detailed_HCLL/stl/shield_8.stl', '/home/jshim/detailed_HCLL/stl/shield_9.stl', '/home/jshim/detailed_HCLL/stl/shield_10.stl', '/home/jshim/detailed_HCLL/stl/shield_11.stl', '/home/jshim/detailed_HCLL/stl/shield_12.stl', '/home/jshim/detailed_HCLL/stl/shield_13.stl', '/home/jshim/detailed_HCLL/stl/shield_14.stl'], 'part': <Shape object at 0x85ade90>}, 'armour': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/armour_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/armour_mod1_2.stl'], 'part': [<Shape object at 0x843a010>], 'step_filename': '/home/jshim/detailed_HCLL/step/armour_mod1.step'}, 'tf_coils': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_coils_1.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_2.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_3.stl', '/home/jshim/de ...
# (defaultdict(<type 'dict'>, {'slice_first_wall_homogenised': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/slice_first_wall_homogenised_mod1_1.stl'], 'part': [<Shape object at 0x846d0c0>], 'step_filename': '/home/jshim/detailed_HCLL/step/slice_first_wall_homogenised_mod1.step'}, 'tf_case': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_case_1.stl', '/home/jshim/detailed_HCLL/stl/tf_case_2.stl', '/home/jshim/detailed_HCLL/stl/tf_case_3.stl', '/home/jshim/detailed_HCLL/stl/tf_case_4.stl', '/home/jshim/detailed_HCLL/stl/tf_case_5.stl', '/home/jshim/detailed_HCLL/stl/tf_case_6.stl', '/home/jshim/detailed_HCLL/stl/tf_case_7.stl', '/home/jshim/detailed_HCLL/stl/tf_case_8.stl', '/home/jshim/detailed_HCLL/stl/tf_case_9.stl', '/home/jshim/detailed_HCLL/stl/tf_case_10.stl', '/home/jshim/detailed_HCLL/stl/tf_case_11.stl', '/home/jshim/detailed_HCLL/stl/tf_case_12.stl', '/home/jshim/detailed_HCLL/stl/tf_case_13.stl', '/home/jshim/detailed_HCLL/stl/tf_case_14.stl', '/home/jshim/detailed_HCLL/stl/tf_case_15.stl', '/home/jshim/detailed_HCLL/stl/tf_case_16.stl', '/home/jshim/detailed_HCLL/stl/tf_case_17.stl', '/home/jshim/detailed_HCLL/stl/tf_case_18.stl', '/home/jshim/detailed_HCLL/stl/tf_case_19.stl', '/home/jshim/detailed_HCLL/stl/tf_case_20.stl', '/home/jshim/detailed_HCLL/stl/tf_case_21.stl', '/home/jshim/detailed_HCLL/stl/tf_case_22.stl', '/home/jshim/detailed_HCLL/stl/tf_case_23.stl', '/home/jshim/detailed_HCLL/stl/tf_case_24.stl', '/home/jshim/detailed_HCLL/stl/tf_case_25.stl', '/home/jshim/detailed_HCLL/stl/tf_case_26.stl', '/home/jshim/detailed_HCLL/stl/tf_case_27.stl', '/home/jshim/detailed_HCLL/stl/tf_case_28.stl', '/home/jshim/detailed_HCLL/stl/tf_case_29.stl', '/home/jshim/detailed_HCLL/stl/tf_case_30.stl', '/home/jshim/detailed_HCLL/stl/tf_case_31.stl', '/home/jshim/detailed_HCLL/stl/tf_case_32.stl'], 'part': <Shape object at 0x8ffeab0>}, 'central_solenoid': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/central_solenoid_1.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_2.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_3.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_4.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_5.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_6.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_7.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_8.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_9.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_10.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_11.stl'], 'part': <Shape object at 0x8b4c280>}, 'back_lithium_lead': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_2.stl'], 'part': [<Shape object at 0x83f7210>], 'step_filename': '/home/jshim/detailed_HCLL/step/back_lithium_lead_mod1.step'}, 'shield': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/shield_1.stl', '/home/jshim/detailed_HCLL/stl/shield_2.stl', '/home/jshim/detailed_HCLL/stl/shield_3.stl', '/home/jshim/detailed_HCLL/stl/shield_4.stl', '/home/jshim/detailed_HCLL/stl/shield_5.stl', '/home/jshim/detailed_HCLL/stl/shield_6.stl', '/home/jshim/detailed_HCLL/stl/shield_7.stl', '/home/jshim/detailed_HCLL/stl/shield_8.stl', '/home/jshim/detailed_HCLL/stl/shield_9.stl', '/home/jshim/detailed_HCLL/stl/shield_10.stl', '/home/jshim/detailed_HCLL/stl/shield_11.stl', '/home/jshim/detailed_HCLL/stl/shield_12.stl', '/home/jshim/detailed_HCLL/stl/shield_13.stl', '/home/jshim/detailed_HCLL/stl/shield_14.stl'], 'part': <Shape object at 0x85ade90>}, 'armour': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/armour_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/armour_mod1_2.stl'], 'part': [<Shape object at 0x843a010>], 'step_filename': '/home/jshim/detailed_HCLL/step/armour_mod1.step'}, 'tf_coils': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_coils_1.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_2.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_3.stl', '/home/jshim/de ...
# (defaultdict(<type 'dict'>, {'slice_first_wall_homogenised': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/slice_first_wall_homogenised_mod1_1.stl'], 'part': [<Shape object at 0x846d0c0>], 'step_filename': '/home/jshim/detailed_HCLL/step/slice_first_wall_homogenised_mod1.step'}, 'tf_case': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_case_1.stl', '/home/jshim/detailed_HCLL/stl/tf_case_2.stl', '/home/jshim/detailed_HCLL/stl/tf_case_3.stl', '/home/jshim/detailed_HCLL/stl/tf_case_4.stl', '/home/jshim/detailed_HCLL/stl/tf_case_5.stl', '/home/jshim/detailed_HCLL/stl/tf_case_6.stl', '/home/jshim/detailed_HCLL/stl/tf_case_7.stl', '/home/jshim/detailed_HCLL/stl/tf_case_8.stl', '/home/jshim/detailed_HCLL/stl/tf_case_9.stl', '/home/jshim/detailed_HCLL/stl/tf_case_10.stl', '/home/jshim/detailed_HCLL/stl/tf_case_11.stl', '/home/jshim/detailed_HCLL/stl/tf_case_12.stl', '/home/jshim/detailed_HCLL/stl/tf_case_13.stl', '/home/jshim/detailed_HCLL/stl/tf_case_14.stl', '/home/jshim/detailed_HCLL/stl/tf_case_15.stl', '/home/jshim/detailed_HCLL/stl/tf_case_16.stl', '/home/jshim/detailed_HCLL/stl/tf_case_17.stl', '/home/jshim/detailed_HCLL/stl/tf_case_18.stl', '/home/jshim/detailed_HCLL/stl/tf_case_19.stl', '/home/jshim/detailed_HCLL/stl/tf_case_20.stl', '/home/jshim/detailed_HCLL/stl/tf_case_21.stl', '/home/jshim/detailed_HCLL/stl/tf_case_22.stl', '/home/jshim/detailed_HCLL/stl/tf_case_23.stl', '/home/jshim/detailed_HCLL/stl/tf_case_24.stl', '/home/jshim/detailed_HCLL/stl/tf_case_25.stl', '/home/jshim/detailed_HCLL/stl/tf_case_26.stl', '/home/jshim/detailed_HCLL/stl/tf_case_27.stl', '/home/jshim/detailed_HCLL/stl/tf_case_28.stl', '/home/jshim/detailed_HCLL/stl/tf_case_29.stl', '/home/jshim/detailed_HCLL/stl/tf_case_30.stl', '/home/jshim/detailed_HCLL/stl/tf_case_31.stl', '/home/jshim/detailed_HCLL/stl/tf_case_32.stl'], 'part': <Shape object at 0x8ffeab0>}, 'central_solenoid': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/central_solenoid_1.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_2.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_3.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_4.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_5.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_6.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_7.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_8.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_9.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_10.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_11.stl'], 'part': <Shape object at 0x8b4c280>}, 'back_lithium_lead': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_2.stl'], 'part': [<Shape object at 0x83f7210>], 'step_filename': '/home/jshim/detailed_HCLL/step/back_lithium_lead_mod1.step'}, 'shield': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/shield_1.stl', '/home/jshim/detailed_HCLL/stl/shield_2.stl', '/home/jshim/detailed_HCLL/stl/shield_3.stl', '/home/jshim/detailed_HCLL/stl/shield_4.stl', '/home/jshim/detailed_HCLL/stl/shield_5.stl', '/home/jshim/detailed_HCLL/stl/shield_6.stl', '/home/jshim/detailed_HCLL/stl/shield_7.stl', '/home/jshim/detailed_HCLL/stl/shield_8.stl', '/home/jshim/detailed_HCLL/stl/shield_9.stl', '/home/jshim/detailed_HCLL/stl/shield_10.stl', '/home/jshim/detailed_HCLL/stl/shield_11.stl', '/home/jshim/detailed_HCLL/stl/shield_12.stl', '/home/jshim/detailed_HCLL/stl/shield_13.stl', '/home/jshim/detailed_HCLL/stl/shield_14.stl'], 'part': <Shape object at 0x85ade90>}, 'armour': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/armour_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/armour_mod1_2.stl'], 'part': [<Shape object at 0x843a010>], 'step_filename': '/home/jshim/detailed_HCLL/step/armour_mod1.step'}, 'tf_coils': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_coils_1.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_2.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_3.stl', '/home/jshim/de ...
# (defaultdict(<type 'dict'>, {'slice_first_wall_homogenised': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/slice_first_wall_homogenised_mod1_1.stl'], 'part': [<Shape object at 0x846d0c0>], 'step_filename': '/home/jshim/detailed_HCLL/step/slice_first_wall_homogenised_mod1.step'}, 'tf_case': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_case_1.stl', '/home/jshim/detailed_HCLL/stl/tf_case_2.stl', '/home/jshim/detailed_HCLL/stl/tf_case_3.stl', '/home/jshim/detailed_HCLL/stl/tf_case_4.stl', '/home/jshim/detailed_HCLL/stl/tf_case_5.stl', '/home/jshim/detailed_HCLL/stl/tf_case_6.stl', '/home/jshim/detailed_HCLL/stl/tf_case_7.stl', '/home/jshim/detailed_HCLL/stl/tf_case_8.stl', '/home/jshim/detailed_HCLL/stl/tf_case_9.stl', '/home/jshim/detailed_HCLL/stl/tf_case_10.stl', '/home/jshim/detailed_HCLL/stl/tf_case_11.stl', '/home/jshim/detailed_HCLL/stl/tf_case_12.stl', '/home/jshim/detailed_HCLL/stl/tf_case_13.stl', '/home/jshim/detailed_HCLL/stl/tf_case_14.stl', '/home/jshim/detailed_HCLL/stl/tf_case_15.stl', '/home/jshim/detailed_HCLL/stl/tf_case_16.stl', '/home/jshim/detailed_HCLL/stl/tf_case_17.stl', '/home/jshim/detailed_HCLL/stl/tf_case_18.stl', '/home/jshim/detailed_HCLL/stl/tf_case_19.stl', '/home/jshim/detailed_HCLL/stl/tf_case_20.stl', '/home/jshim/detailed_HCLL/stl/tf_case_21.stl', '/home/jshim/detailed_HCLL/stl/tf_case_22.stl', '/home/jshim/detailed_HCLL/stl/tf_case_23.stl', '/home/jshim/detailed_HCLL/stl/tf_case_24.stl', '/home/jshim/detailed_HCLL/stl/tf_case_25.stl', '/home/jshim/detailed_HCLL/stl/tf_case_26.stl', '/home/jshim/detailed_HCLL/stl/tf_case_27.stl', '/home/jshim/detailed_HCLL/stl/tf_case_28.stl', '/home/jshim/detailed_HCLL/stl/tf_case_29.stl', '/home/jshim/detailed_HCLL/stl/tf_case_30.stl', '/home/jshim/detailed_HCLL/stl/tf_case_31.stl', '/home/jshim/detailed_HCLL/stl/tf_case_32.stl'], 'part': <Shape object at 0x8ffeab0>}, 'central_solenoid': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/central_solenoid_1.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_2.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_3.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_4.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_5.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_6.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_7.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_8.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_9.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_10.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_11.stl'], 'part': <Shape object at 0x8b4c280>}, 'back_lithium_lead': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_2.stl'], 'part': [<Shape object at 0x83f7210>], 'step_filename': '/home/jshim/detailed_HCLL/step/back_lithium_lead_mod1.step'}, 'shield': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/shield_1.stl', '/home/jshim/detailed_HCLL/stl/shield_2.stl', '/home/jshim/detailed_HCLL/stl/shield_3.stl', '/home/jshim/detailed_HCLL/stl/shield_4.stl', '/home/jshim/detailed_HCLL/stl/shield_5.stl', '/home/jshim/detailed_HCLL/stl/shield_6.stl', '/home/jshim/detailed_HCLL/stl/shield_7.stl', '/home/jshim/detailed_HCLL/stl/shield_8.stl', '/home/jshim/detailed_HCLL/stl/shield_9.stl', '/home/jshim/detailed_HCLL/stl/shield_10.stl', '/home/jshim/detailed_HCLL/stl/shield_11.stl', '/home/jshim/detailed_HCLL/stl/shield_12.stl', '/home/jshim/detailed_HCLL/stl/shield_13.stl', '/home/jshim/detailed_HCLL/stl/shield_14.stl'], 'part': <Shape object at 0x85ade90>}, 'armour': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/armour_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/armour_mod1_2.stl'], 'part': [<Shape object at 0x843a010>], 'step_filename': '/home/jshim/detailed_HCLL/step/armour_mod1.step'}, 'tf_coils': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_coils_1.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_2.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_3.stl', '/home/jshim/de ...
# (defaultdict(<type 'dict'>, {'slice_first_wall_homogenised': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/slice_first_wall_homogenised_mod1_1.stl'], 'part': [<Shape object at 0x846d0c0>], 'step_filename': '/home/jshim/detailed_HCLL/step/slice_first_wall_homogenised_mod1.step'}, 'tf_case': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_case_1.stl', '/home/jshim/detailed_HCLL/stl/tf_case_2.stl', '/home/jshim/detailed_HCLL/stl/tf_case_3.stl', '/home/jshim/detailed_HCLL/stl/tf_case_4.stl', '/home/jshim/detailed_HCLL/stl/tf_case_5.stl', '/home/jshim/detailed_HCLL/stl/tf_case_6.stl', '/home/jshim/detailed_HCLL/stl/tf_case_7.stl', '/home/jshim/detailed_HCLL/stl/tf_case_8.stl', '/home/jshim/detailed_HCLL/stl/tf_case_9.stl', '/home/jshim/detailed_HCLL/stl/tf_case_10.stl', '/home/jshim/detailed_HCLL/stl/tf_case_11.stl', '/home/jshim/detailed_HCLL/stl/tf_case_12.stl', '/home/jshim/detailed_HCLL/stl/tf_case_13.stl', '/home/jshim/detailed_HCLL/stl/tf_case_14.stl', '/home/jshim/detailed_HCLL/stl/tf_case_15.stl', '/home/jshim/detailed_HCLL/stl/tf_case_16.stl', '/home/jshim/detailed_HCLL/stl/tf_case_17.stl', '/home/jshim/detailed_HCLL/stl/tf_case_18.stl', '/home/jshim/detailed_HCLL/stl/tf_case_19.stl', '/home/jshim/detailed_HCLL/stl/tf_case_20.stl', '/home/jshim/detailed_HCLL/stl/tf_case_21.stl', '/home/jshim/detailed_HCLL/stl/tf_case_22.stl', '/home/jshim/detailed_HCLL/stl/tf_case_23.stl', '/home/jshim/detailed_HCLL/stl/tf_case_24.stl', '/home/jshim/detailed_HCLL/stl/tf_case_25.stl', '/home/jshim/detailed_HCLL/stl/tf_case_26.stl', '/home/jshim/detailed_HCLL/stl/tf_case_27.stl', '/home/jshim/detailed_HCLL/stl/tf_case_28.stl', '/home/jshim/detailed_HCLL/stl/tf_case_29.stl', '/home/jshim/detailed_HCLL/stl/tf_case_30.stl', '/home/jshim/detailed_HCLL/stl/tf_case_31.stl', '/home/jshim/detailed_HCLL/stl/tf_case_32.stl'], 'part': <Shape object at 0x8ffeab0>}, 'central_solenoid': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/central_solenoid_1.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_2.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_3.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_4.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_5.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_6.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_7.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_8.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_9.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_10.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_11.stl'], 'part': <Shape object at 0x8b4c280>}, 'back_lithium_lead': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_2.stl'], 'part': [<Shape object at 0x83f7210>], 'step_filename': '/home/jshim/detailed_HCLL/step/back_lithium_lead_mod1.step'}, 'shield': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/shield_1.stl', '/home/jshim/detailed_HCLL/stl/shield_2.stl', '/home/jshim/detailed_HCLL/stl/shield_3.stl', '/home/jshim/detailed_HCLL/stl/shield_4.stl', '/home/jshim/detailed_HCLL/stl/shield_5.stl', '/home/jshim/detailed_HCLL/stl/shield_6.stl', '/home/jshim/detailed_HCLL/stl/shield_7.stl', '/home/jshim/detailed_HCLL/stl/shield_8.stl', '/home/jshim/detailed_HCLL/stl/shield_9.stl', '/home/jshim/detailed_HCLL/stl/shield_10.stl', '/home/jshim/detailed_HCLL/stl/shield_11.stl', '/home/jshim/detailed_HCLL/stl/shield_12.stl', '/home/jshim/detailed_HCLL/stl/shield_13.stl', '/home/jshim/detailed_HCLL/stl/shield_14.stl'], 'part': <Shape object at 0x85ade90>}, 'armour': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/armour_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/armour_mod1_2.stl'], 'part': [<Shape object at 0x843a010>], 'step_filename': '/home/jshim/detailed_HCLL/step/armour_mod1.step'}, 'tf_coils': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_coils_1.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_2.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_3.stl', '/home/jshim/de ...
# (defaultdict(<type 'dict'>, {'slice_first_wall_homogenised': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/slice_first_wall_homogenised_mod1_1.stl'], 'part': [<Shape object at 0x846d0c0>], 'step_filename': '/home/jshim/detailed_HCLL/step/slice_first_wall_homogenised_mod1.step'}, 'tf_case': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_case_1.stl', '/home/jshim/detailed_HCLL/stl/tf_case_2.stl', '/home/jshim/detailed_HCLL/stl/tf_case_3.stl', '/home/jshim/detailed_HCLL/stl/tf_case_4.stl', '/home/jshim/detailed_HCLL/stl/tf_case_5.stl', '/home/jshim/detailed_HCLL/stl/tf_case_6.stl', '/home/jshim/detailed_HCLL/stl/tf_case_7.stl', '/home/jshim/detailed_HCLL/stl/tf_case_8.stl', '/home/jshim/detailed_HCLL/stl/tf_case_9.stl', '/home/jshim/detailed_HCLL/stl/tf_case_10.stl', '/home/jshim/detailed_HCLL/stl/tf_case_11.stl', '/home/jshim/detailed_HCLL/stl/tf_case_12.stl', '/home/jshim/detailed_HCLL/stl/tf_case_13.stl', '/home/jshim/detailed_HCLL/stl/tf_case_14.stl', '/home/jshim/detailed_HCLL/stl/tf_case_15.stl', '/home/jshim/detailed_HCLL/stl/tf_case_16.stl', '/home/jshim/detailed_HCLL/stl/tf_case_17.stl', '/home/jshim/detailed_HCLL/stl/tf_case_18.stl', '/home/jshim/detailed_HCLL/stl/tf_case_19.stl', '/home/jshim/detailed_HCLL/stl/tf_case_20.stl', '/home/jshim/detailed_HCLL/stl/tf_case_21.stl', '/home/jshim/detailed_HCLL/stl/tf_case_22.stl', '/home/jshim/detailed_HCLL/stl/tf_case_23.stl', '/home/jshim/detailed_HCLL/stl/tf_case_24.stl', '/home/jshim/detailed_HCLL/stl/tf_case_25.stl', '/home/jshim/detailed_HCLL/stl/tf_case_26.stl', '/home/jshim/detailed_HCLL/stl/tf_case_27.stl', '/home/jshim/detailed_HCLL/stl/tf_case_28.stl', '/home/jshim/detailed_HCLL/stl/tf_case_29.stl', '/home/jshim/detailed_HCLL/stl/tf_case_30.stl', '/home/jshim/detailed_HCLL/stl/tf_case_31.stl', '/home/jshim/detailed_HCLL/stl/tf_case_32.stl'], 'part': <Shape object at 0x8ffeab0>}, 'central_solenoid': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/central_solenoid_1.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_2.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_3.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_4.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_5.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_6.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_7.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_8.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_9.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_10.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_11.stl'], 'part': <Shape object at 0x8b4c280>}, 'back_lithium_lead': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_2.stl'], 'part': [<Shape object at 0x83f7210>], 'step_filename': '/home/jshim/detailed_HCLL/step/back_lithium_lead_mod1.step'}, 'shield': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/shield_1.stl', '/home/jshim/detailed_HCLL/stl/shield_2.stl', '/home/jshim/detailed_HCLL/stl/shield_3.stl', '/home/jshim/detailed_HCLL/stl/shield_4.stl', '/home/jshim/detailed_HCLL/stl/shield_5.stl', '/home/jshim/detailed_HCLL/stl/shield_6.stl', '/home/jshim/detailed_HCLL/stl/shield_7.stl', '/home/jshim/detailed_HCLL/stl/shield_8.stl', '/home/jshim/detailed_HCLL/stl/shield_9.stl', '/home/jshim/detailed_HCLL/stl/shield_10.stl', '/home/jshim/detailed_HCLL/stl/shield_11.stl', '/home/jshim/detailed_HCLL/stl/shield_12.stl', '/home/jshim/detailed_HCLL/stl/shield_13.stl', '/home/jshim/detailed_HCLL/stl/shield_14.stl'], 'part': <Shape object at 0x85ade90>}, 'armour': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/armour_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/armour_mod1_2.stl'], 'part': [<Shape object at 0x843a010>], 'step_filename': '/home/jshim/detailed_HCLL/step/armour_mod1.step'}, 'tf_coils': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_coils_1.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_2.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_3.stl', '/home/jshim/de ...
# (defaultdict(<type 'dict'>, {'slice_first_wall_homogenised': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/slice_first_wall_homogenised_mod1_1.stl'], 'part': [<Shape object at 0x846d0c0>], 'step_filename': '/home/jshim/detailed_HCLL/step/slice_first_wall_homogenised_mod1.step'}, 'tf_case': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_case_1.stl', '/home/jshim/detailed_HCLL/stl/tf_case_2.stl', '/home/jshim/detailed_HCLL/stl/tf_case_3.stl', '/home/jshim/detailed_HCLL/stl/tf_case_4.stl', '/home/jshim/detailed_HCLL/stl/tf_case_5.stl', '/home/jshim/detailed_HCLL/stl/tf_case_6.stl', '/home/jshim/detailed_HCLL/stl/tf_case_7.stl', '/home/jshim/detailed_HCLL/stl/tf_case_8.stl', '/home/jshim/detailed_HCLL/stl/tf_case_9.stl', '/home/jshim/detailed_HCLL/stl/tf_case_10.stl', '/home/jshim/detailed_HCLL/stl/tf_case_11.stl', '/home/jshim/detailed_HCLL/stl/tf_case_12.stl', '/home/jshim/detailed_HCLL/stl/tf_case_13.stl', '/home/jshim/detailed_HCLL/stl/tf_case_14.stl', '/home/jshim/detailed_HCLL/stl/tf_case_15.stl', '/home/jshim/detailed_HCLL/stl/tf_case_16.stl', '/home/jshim/detailed_HCLL/stl/tf_case_17.stl', '/home/jshim/detailed_HCLL/stl/tf_case_18.stl', '/home/jshim/detailed_HCLL/stl/tf_case_19.stl', '/home/jshim/detailed_HCLL/stl/tf_case_20.stl', '/home/jshim/detailed_HCLL/stl/tf_case_21.stl', '/home/jshim/detailed_HCLL/stl/tf_case_22.stl', '/home/jshim/detailed_HCLL/stl/tf_case_23.stl', '/home/jshim/detailed_HCLL/stl/tf_case_24.stl', '/home/jshim/detailed_HCLL/stl/tf_case_25.stl', '/home/jshim/detailed_HCLL/stl/tf_case_26.stl', '/home/jshim/detailed_HCLL/stl/tf_case_27.stl', '/home/jshim/detailed_HCLL/stl/tf_case_28.stl', '/home/jshim/detailed_HCLL/stl/tf_case_29.stl', '/home/jshim/detailed_HCLL/stl/tf_case_30.stl', '/home/jshim/detailed_HCLL/stl/tf_case_31.stl', '/home/jshim/detailed_HCLL/stl/tf_case_32.stl'], 'part': <Shape object at 0x8ffeab0>}, 'central_solenoid': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/central_solenoid_1.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_2.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_3.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_4.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_5.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_6.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_7.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_8.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_9.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_10.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_11.stl'], 'part': <Shape object at 0x8b4c280>}, 'back_lithium_lead': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_2.stl'], 'part': [<Shape object at 0x83f7210>], 'step_filename': '/home/jshim/detailed_HCLL/step/back_lithium_lead_mod1.step'}, 'shield': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/shield_1.stl', '/home/jshim/detailed_HCLL/stl/shield_2.stl', '/home/jshim/detailed_HCLL/stl/shield_3.stl', '/home/jshim/detailed_HCLL/stl/shield_4.stl', '/home/jshim/detailed_HCLL/stl/shield_5.stl', '/home/jshim/detailed_HCLL/stl/shield_6.stl', '/home/jshim/detailed_HCLL/stl/shield_7.stl', '/home/jshim/detailed_HCLL/stl/shield_8.stl', '/home/jshim/detailed_HCLL/stl/shield_9.stl', '/home/jshim/detailed_HCLL/stl/shield_10.stl', '/home/jshim/detailed_HCLL/stl/shield_11.stl', '/home/jshim/detailed_HCLL/stl/shield_12.stl', '/home/jshim/detailed_HCLL/stl/shield_13.stl', '/home/jshim/detailed_HCLL/stl/shield_14.stl'], 'part': <Shape object at 0x85ade90>}, 'armour': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/armour_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/armour_mod1_2.stl'], 'part': [<Shape object at 0x843a010>], 'step_filename': '/home/jshim/detailed_HCLL/step/armour_mod1.step'}, 'tf_coils': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_coils_1.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_2.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_3.stl', '/home/jshim/de ...
# (defaultdict(<type 'dict'>, {'slice_first_wall_homogenised': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/slice_first_wall_homogenised_mod1_1.stl'], 'part': [<Shape object at 0x846d0c0>], 'step_filename': '/home/jshim/detailed_HCLL/step/slice_first_wall_homogenised_mod1.step'}, 'tf_case': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_case_1.stl', '/home/jshim/detailed_HCLL/stl/tf_case_2.stl', '/home/jshim/detailed_HCLL/stl/tf_case_3.stl', '/home/jshim/detailed_HCLL/stl/tf_case_4.stl', '/home/jshim/detailed_HCLL/stl/tf_case_5.stl', '/home/jshim/detailed_HCLL/stl/tf_case_6.stl', '/home/jshim/detailed_HCLL/stl/tf_case_7.stl', '/home/jshim/detailed_HCLL/stl/tf_case_8.stl', '/home/jshim/detailed_HCLL/stl/tf_case_9.stl', '/home/jshim/detailed_HCLL/stl/tf_case_10.stl', '/home/jshim/detailed_HCLL/stl/tf_case_11.stl', '/home/jshim/detailed_HCLL/stl/tf_case_12.stl', '/home/jshim/detailed_HCLL/stl/tf_case_13.stl', '/home/jshim/detailed_HCLL/stl/tf_case_14.stl', '/home/jshim/detailed_HCLL/stl/tf_case_15.stl', '/home/jshim/detailed_HCLL/stl/tf_case_16.stl', '/home/jshim/detailed_HCLL/stl/tf_case_17.stl', '/home/jshim/detailed_HCLL/stl/tf_case_18.stl', '/home/jshim/detailed_HCLL/stl/tf_case_19.stl', '/home/jshim/detailed_HCLL/stl/tf_case_20.stl', '/home/jshim/detailed_HCLL/stl/tf_case_21.stl', '/home/jshim/detailed_HCLL/stl/tf_case_22.stl', '/home/jshim/detailed_HCLL/stl/tf_case_23.stl', '/home/jshim/detailed_HCLL/stl/tf_case_24.stl', '/home/jshim/detailed_HCLL/stl/tf_case_25.stl', '/home/jshim/detailed_HCLL/stl/tf_case_26.stl', '/home/jshim/detailed_HCLL/stl/tf_case_27.stl', '/home/jshim/detailed_HCLL/stl/tf_case_28.stl', '/home/jshim/detailed_HCLL/stl/tf_case_29.stl', '/home/jshim/detailed_HCLL/stl/tf_case_30.stl', '/home/jshim/detailed_HCLL/stl/tf_case_31.stl', '/home/jshim/detailed_HCLL/stl/tf_case_32.stl'], 'part': <Shape object at 0x8ffeab0>}, 'central_solenoid': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/central_solenoid_1.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_2.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_3.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_4.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_5.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_6.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_7.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_8.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_9.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_10.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_11.stl'], 'part': <Shape object at 0x8b4c280>}, 'back_lithium_lead': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_2.stl'], 'part': [<Shape object at 0x83f7210>], 'step_filename': '/home/jshim/detailed_HCLL/step/back_lithium_lead_mod1.step'}, 'shield': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/shield_1.stl', '/home/jshim/detailed_HCLL/stl/shield_2.stl', '/home/jshim/detailed_HCLL/stl/shield_3.stl', '/home/jshim/detailed_HCLL/stl/shield_4.stl', '/home/jshim/detailed_HCLL/stl/shield_5.stl', '/home/jshim/detailed_HCLL/stl/shield_6.stl', '/home/jshim/detailed_HCLL/stl/shield_7.stl', '/home/jshim/detailed_HCLL/stl/shield_8.stl', '/home/jshim/detailed_HCLL/stl/shield_9.stl', '/home/jshim/detailed_HCLL/stl/shield_10.stl', '/home/jshim/detailed_HCLL/stl/shield_11.stl', '/home/jshim/detailed_HCLL/stl/shield_12.stl', '/home/jshim/detailed_HCLL/stl/shield_13.stl', '/home/jshim/detailed_HCLL/stl/shield_14.stl'], 'part': <Shape object at 0x85ade90>}, 'armour': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/armour_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/armour_mod1_2.stl'], 'part': [<Shape object at 0x843a010>], 'step_filename': '/home/jshim/detailed_HCLL/step/armour_mod1.step'}, 'tf_coils': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_coils_1.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_2.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_3.stl', '/home/jshim/de ...
# (defaultdict(<type 'dict'>, {'slice_first_wall_homogenised': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/slice_first_wall_homogenised_mod1_1.stl'], 'part': [<Shape object at 0x846d0c0>], 'step_filename': '/home/jshim/detailed_HCLL/step/slice_first_wall_homogenised_mod1.step'}, 'tf_case': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_case_1.stl', '/home/jshim/detailed_HCLL/stl/tf_case_2.stl', '/home/jshim/detailed_HCLL/stl/tf_case_3.stl', '/home/jshim/detailed_HCLL/stl/tf_case_4.stl', '/home/jshim/detailed_HCLL/stl/tf_case_5.stl', '/home/jshim/detailed_HCLL/stl/tf_case_6.stl', '/home/jshim/detailed_HCLL/stl/tf_case_7.stl', '/home/jshim/detailed_HCLL/stl/tf_case_8.stl', '/home/jshim/detailed_HCLL/stl/tf_case_9.stl', '/home/jshim/detailed_HCLL/stl/tf_case_10.stl', '/home/jshim/detailed_HCLL/stl/tf_case_11.stl', '/home/jshim/detailed_HCLL/stl/tf_case_12.stl', '/home/jshim/detailed_HCLL/stl/tf_case_13.stl', '/home/jshim/detailed_HCLL/stl/tf_case_14.stl', '/home/jshim/detailed_HCLL/stl/tf_case_15.stl', '/home/jshim/detailed_HCLL/stl/tf_case_16.stl', '/home/jshim/detailed_HCLL/stl/tf_case_17.stl', '/home/jshim/detailed_HCLL/stl/tf_case_18.stl', '/home/jshim/detailed_HCLL/stl/tf_case_19.stl', '/home/jshim/detailed_HCLL/stl/tf_case_20.stl', '/home/jshim/detailed_HCLL/stl/tf_case_21.stl', '/home/jshim/detailed_HCLL/stl/tf_case_22.stl', '/home/jshim/detailed_HCLL/stl/tf_case_23.stl', '/home/jshim/detailed_HCLL/stl/tf_case_24.stl', '/home/jshim/detailed_HCLL/stl/tf_case_25.stl', '/home/jshim/detailed_HCLL/stl/tf_case_26.stl', '/home/jshim/detailed_HCLL/stl/tf_case_27.stl', '/home/jshim/detailed_HCLL/stl/tf_case_28.stl', '/home/jshim/detailed_HCLL/stl/tf_case_29.stl', '/home/jshim/detailed_HCLL/stl/tf_case_30.stl', '/home/jshim/detailed_HCLL/stl/tf_case_31.stl', '/home/jshim/detailed_HCLL/stl/tf_case_32.stl'], 'part': <Shape object at 0x8ffeab0>}, 'central_solenoid': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/central_solenoid_1.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_2.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_3.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_4.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_5.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_6.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_7.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_8.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_9.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_10.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_11.stl'], 'part': <Shape object at 0x8b4c280>}, 'back_lithium_lead': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_2.stl'], 'part': [<Shape object at 0x83f7210>], 'step_filename': '/home/jshim/detailed_HCLL/step/back_lithium_lead_mod1.step'}, 'shield': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/shield_1.stl', '/home/jshim/detailed_HCLL/stl/shield_2.stl', '/home/jshim/detailed_HCLL/stl/shield_3.stl', '/home/jshim/detailed_HCLL/stl/shield_4.stl', '/home/jshim/detailed_HCLL/stl/shield_5.stl', '/home/jshim/detailed_HCLL/stl/shield_6.stl', '/home/jshim/detailed_HCLL/stl/shield_7.stl', '/home/jshim/detailed_HCLL/stl/shield_8.stl', '/home/jshim/detailed_HCLL/stl/shield_9.stl', '/home/jshim/detailed_HCLL/stl/shield_10.stl', '/home/jshim/detailed_HCLL/stl/shield_11.stl', '/home/jshim/detailed_HCLL/stl/shield_12.stl', '/home/jshim/detailed_HCLL/stl/shield_13.stl', '/home/jshim/detailed_HCLL/stl/shield_14.stl'], 'part': <Shape object at 0x85ade90>}, 'armour': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/armour_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/armour_mod1_2.stl'], 'part': [<Shape object at 0x843a010>], 'step_filename': '/home/jshim/detailed_HCLL/step/armour_mod1.step'}, 'tf_coils': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_coils_1.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_2.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_3.stl', '/home/jshim/de ...
# ...
# (defaultdict(<type 'dict'>, {'slice_first_wall_homogenised': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/slice_first_wall_homogenised_mod1_1.stl'], 'part': [<Shape object at 0x846d0c0>], 'step_filename': '/home/jshim/detailed_HCLL/step/slice_first_wall_homogenised_mod1.step'}, 'tf_case': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_case_1.stl', '/home/jshim/detailed_HCLL/stl/tf_case_2.stl', '/home/jshim/detailed_HCLL/stl/tf_case_3.stl', '/home/jshim/detailed_HCLL/stl/tf_case_4.stl', '/home/jshim/detailed_HCLL/stl/tf_case_5.stl', '/home/jshim/detailed_HCLL/stl/tf_case_6.stl', '/home/jshim/detailed_HCLL/stl/tf_case_7.stl', '/home/jshim/detailed_HCLL/stl/tf_case_8.stl', '/home/jshim/detailed_HCLL/stl/tf_case_9.stl', '/home/jshim/detailed_HCLL/stl/tf_case_10.stl', '/home/jshim/detailed_HCLL/stl/tf_case_11.stl', '/home/jshim/detailed_HCLL/stl/tf_case_12.stl', '/home/jshim/detailed_HCLL/stl/tf_case_13.stl', '/home/jshim/detailed_HCLL/stl/tf_case_14.stl', '/home/jshim/detailed_HCLL/stl/tf_case_15.stl', '/home/jshim/detailed_HCLL/stl/tf_case_16.stl', '/home/jshim/detailed_HCLL/stl/tf_case_17.stl', '/home/jshim/detailed_HCLL/stl/tf_case_18.stl', '/home/jshim/detailed_HCLL/stl/tf_case_19.stl', '/home/jshim/detailed_HCLL/stl/tf_case_20.stl', '/home/jshim/detailed_HCLL/stl/tf_case_21.stl', '/home/jshim/detailed_HCLL/stl/tf_case_22.stl', '/home/jshim/detailed_HCLL/stl/tf_case_23.stl', '/home/jshim/detailed_HCLL/stl/tf_case_24.stl', '/home/jshim/detailed_HCLL/stl/tf_case_25.stl', '/home/jshim/detailed_HCLL/stl/tf_case_26.stl', '/home/jshim/detailed_HCLL/stl/tf_case_27.stl', '/home/jshim/detailed_HCLL/stl/tf_case_28.stl', '/home/jshim/detailed_HCLL/stl/tf_case_29.stl', '/home/jshim/detailed_HCLL/stl/tf_case_30.stl', '/home/jshim/detailed_HCLL/stl/tf_case_31.stl', '/home/jshim/detailed_HCLL/stl/tf_case_32.stl'], 'part': <Shape object at 0x8ffeab0>}, 'central_solenoid': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/central_solenoid_1.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_2.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_3.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_4.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_5.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_6.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_7.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_8.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_9.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_10.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_11.stl'], 'part': <Shape object at 0x8b4c280>}, 'back_lithium_lead': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_2.stl'], 'part': [<Shape object at 0x83f7210>], 'step_filename': '/home/jshim/detailed_HCLL/step/back_lithium_lead_mod1.step'}, 'shield': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/shield_1.stl', '/home/jshim/detailed_HCLL/stl/shield_2.stl', '/home/jshim/detailed_HCLL/stl/shield_3.stl', '/home/jshim/detailed_HCLL/stl/shield_4.stl', '/home/jshim/detailed_HCLL/stl/shield_5.stl', '/home/jshim/detailed_HCLL/stl/shield_6.stl', '/home/jshim/detailed_HCLL/stl/shield_7.stl', '/home/jshim/detailed_HCLL/stl/shield_8.stl', '/home/jshim/detailed_HCLL/stl/shield_9.stl', '/home/jshim/detailed_HCLL/stl/shield_10.stl', '/home/jshim/detailed_HCLL/stl/shield_11.stl', '/home/jshim/detailed_HCLL/stl/shield_12.stl', '/home/jshim/detailed_HCLL/stl/shield_13.stl', '/home/jshim/detailed_HCLL/stl/shield_14.stl'], 'part': <Shape object at 0x85ade90>}, 'armour': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/armour_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/armour_mod1_2.stl'], 'part': [<Shape object at 0x843a010>], 'step_filename': '/home/jshim/detailed_HCLL/step/armour_mod1.step'}, 'tf_coils': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_coils_1.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_2.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_3.stl', '/home/jshim/de ...
# (defaultdict(<type 'dict'>, {'slice_first_wall_homogenised': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/slice_first_wall_homogenised_mod1_1.stl'], 'part': [<Shape object at 0x846d0c0>], 'step_filename': '/home/jshim/detailed_HCLL/step/slice_first_wall_homogenised_mod1.step'}, 'tf_case': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_case_1.stl', '/home/jshim/detailed_HCLL/stl/tf_case_2.stl', '/home/jshim/detailed_HCLL/stl/tf_case_3.stl', '/home/jshim/detailed_HCLL/stl/tf_case_4.stl', '/home/jshim/detailed_HCLL/stl/tf_case_5.stl', '/home/jshim/detailed_HCLL/stl/tf_case_6.stl', '/home/jshim/detailed_HCLL/stl/tf_case_7.stl', '/home/jshim/detailed_HCLL/stl/tf_case_8.stl', '/home/jshim/detailed_HCLL/stl/tf_case_9.stl', '/home/jshim/detailed_HCLL/stl/tf_case_10.stl', '/home/jshim/detailed_HCLL/stl/tf_case_11.stl', '/home/jshim/detailed_HCLL/stl/tf_case_12.stl', '/home/jshim/detailed_HCLL/stl/tf_case_13.stl', '/home/jshim/detailed_HCLL/stl/tf_case_14.stl', '/home/jshim/detailed_HCLL/stl/tf_case_15.stl', '/home/jshim/detailed_HCLL/stl/tf_case_16.stl', '/home/jshim/detailed_HCLL/stl/tf_case_17.stl', '/home/jshim/detailed_HCLL/stl/tf_case_18.stl', '/home/jshim/detailed_HCLL/stl/tf_case_19.stl', '/home/jshim/detailed_HCLL/stl/tf_case_20.stl', '/home/jshim/detailed_HCLL/stl/tf_case_21.stl', '/home/jshim/detailed_HCLL/stl/tf_case_22.stl', '/home/jshim/detailed_HCLL/stl/tf_case_23.stl', '/home/jshim/detailed_HCLL/stl/tf_case_24.stl', '/home/jshim/detailed_HCLL/stl/tf_case_25.stl', '/home/jshim/detailed_HCLL/stl/tf_case_26.stl', '/home/jshim/detailed_HCLL/stl/tf_case_27.stl', '/home/jshim/detailed_HCLL/stl/tf_case_28.stl', '/home/jshim/detailed_HCLL/stl/tf_case_29.stl', '/home/jshim/detailed_HCLL/stl/tf_case_30.stl', '/home/jshim/detailed_HCLL/stl/tf_case_31.stl', '/home/jshim/detailed_HCLL/stl/tf_case_32.stl'], 'part': <Shape object at 0x8ffeab0>}, 'central_solenoid': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/central_solenoid_1.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_2.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_3.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_4.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_5.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_6.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_7.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_8.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_9.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_10.stl', '/home/jshim/detailed_HCLL/stl/central_solenoid_11.stl'], 'part': <Shape object at 0x8b4c280>}, 'back_lithium_lead': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/back_lithium_lead_mod1_2.stl'], 'part': [<Shape object at 0x83f7210>], 'step_filename': '/home/jshim/detailed_HCLL/step/back_lithium_lead_mod1.step'}, 'shield': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/shield_1.stl', '/home/jshim/detailed_HCLL/stl/shield_2.stl', '/home/jshim/detailed_HCLL/stl/shield_3.stl', '/home/jshim/detailed_HCLL/stl/shield_4.stl', '/home/jshim/detailed_HCLL/stl/shield_5.stl', '/home/jshim/detailed_HCLL/stl/shield_6.stl', '/home/jshim/detailed_HCLL/stl/shield_7.stl', '/home/jshim/detailed_HCLL/stl/shield_8.stl', '/home/jshim/detailed_HCLL/stl/shield_9.stl', '/home/jshim/detailed_HCLL/stl/shield_10.stl', '/home/jshim/detailed_HCLL/stl/shield_11.stl', '/home/jshim/detailed_HCLL/stl/shield_12.stl', '/home/jshim/detailed_HCLL/stl/shield_13.stl', '/home/jshim/detailed_HCLL/stl/shield_14.stl'], 'part': <Shape object at 0x85ade90>}, 'armour': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/armour_mod1_1.stl', '/home/jshim/detailed_HCLL/stl/armour_mod1_2.stl'], 'part': [<Shape object at 0x843a010>], 'step_filename': '/home/jshim/detailed_HCLL/step/armour_mod1.step'}, 'tf_coils': {'stl_filename': ['/home/jshim/detailed_HCLL/stl/tf_coils_1.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_2.stl', '/home/jshim/detailed_HCLL/stl/tf_coils_3.stl', '/home/jshim/de ...
# /home/jshim/detailed_HCLL/stl
# /home/jshim/detailed_HCLL
# /home/jshim/detailed_HCLL
# ('relative director for stl files ', 'stl')
# body slice_first_wall_homogenised-b slice_first_wall_homogenised-c
# body tf_case-b tf_case-c
# body back_plate_2-b back_plate_2-c
# body back_lithium_lead-b back_lithium_lead-c
# body shield-b shield-c
# body armour-b armour-c
# body tf_coils-b tf_coils-c
# body slice_back_plate_2-b slice_back_plate_2-c
# body slice_back_plate_3-b slice_back_plate_3-c
# body slice_back_plate_1-b slice_back_plate_1-c
# body divertor_2nd_layer-b divertor_2nd_layer-c
# body back_helium-b back_helium-c
# body first_wall_material-b first_wall_material-c
# body slice_back_helium-b slice_back_helium-c
# body vacuum_2nd_layer-b vacuum_2nd_layer-c
# body slice_first_wall_coolant-b slice_first_wall_coolant-c
# body cooling_plate_homogenised-b cooling_plate_homogenised-c
# body divertor_1st_layer-b divertor_1st_layer-c
# body plasma-b plasma-c
# body vacuum_1st_layer-b vacuum_1st_layer-c
# body first_wall_coolant-b first_wall_coolant-c
# body first_wall_homogenised-b first_wall_homogenised-c
# body vacuum_3rd_layer-b vacuum_3rd_layer-c
# body slice_first_wall_material-b slice_first_wall_material-c
# body divertor_3rd_layer-b divertor_3rd_layer-c
# body divertor_4th_layer-b divertor_4th_layer-c
# body slice_armour-b slice_armour-c
# body vaccum_vessel_shield-b vaccum_vessel_shield-c
# body slice_back_lithium_lead-b slice_back_lithium_lead-c
# body back_plate_1-b back_plate_1-c
# body back_plate_3-b back_plate_3-c
# body central_solenoid-b central_solenoid-c
# body slice_cooling_plate_material-b slice_cooling_plate_material-c
# body lithium_lead-b lithium_lead-c
# body end_caps_homogenised-b end_caps_homogenised-c
# body blanket_support-b blanket_support-c
# body slice_lithium_lead-b slice_lithium_lead-c
# body manifolder-b manifolder-c
# body ports-b ports-c
# body slice_cooling_plate_coolant-b slice_cooling_plate_coolant-c
# Tally with photons found, including photons in the simulation
# ('nps ', 10000)
# ('batch_size ', 5000.0)
# ('batches ', 2)
# slice_first_wall_homogenised
# tf_case
# back_plate_2
# back_lithium_lead
# shield
# material previous added
# armour
# tf_coils
# slice_back_plate_2
# material previous added
# slice_back_plate_3
# material previous added
# slice_back_plate_1
# material previous added
# divertor_2nd_layer
# back_helium
# first_wall_material
# material previous added
# slice_back_helium
# material previous added
# vacuum_2nd_layer
# slice_first_wall_coolant
# material previous added
# cooling_plate_homogenised
# material previous added
# divertor_1st_layer
# material previous added
# plasma
# vacuum_1st_layer
# material previous added
# first_wall_coolant
# material previous added
# first_wall_homogenised
# material previous added
# vacuum_3rd_layer
# material previous added
# slice_first_wall_material
# material previous added
# divertor_3rd_layer
# material previous added
# divertor_4th_layer
# slice_armour
# material previous added
# vaccum_vessel_shield
# material previous added
# slice_back_lithium_lead
# material previous added
# back_plate_1
# material previous added
# back_plate_3
# material previous added
# central_solenoid
# material previous added
# slice_cooling_plate_material
# material previous added
# lithium_lead
# material previous added
# end_caps_homogenised
# blanket_support
# material previous added
# slice_lithium_lead
# material previous added
# manifolder
# material previous added
# ports
# material previous added
# slice_cooling_plate_coolant
# material previous added
# {'particle_type': 'n', 'mt_number': -55, 'name': 'tbr', 'bodies': ['lithium_lead']}
# {'particle_type': 'n', 'mt_number': -4, 'name': 'neutron_heating', 'bodies': ['armour', 'lithium_lead', 'back_plate_1', 'back_plate_2', 'back_plate_3', 'back_lithium_lead', 'back_helium', 'cooling_plate_homogenised', 'end_caps_homogenised', 'first_wall_homogenised']}
# {'particle_type': 'p', 'mt_number': -26, 'name': 'photon_heating', 'bodies': ['armour', 'lithium_lead', 'back_plate_1', 'back_plate_2', 'back_plate_3', 'back_lithium_lead', 'back_helium', 'cooling_plate_homogenised', 'end_caps_homogenised', 'first_wall_homogenised']}
# ('file written to ', '/home/jshim/detailed_HCLL/serpent_input_file.serp')

# %%
neutronics_parameters = define_neutronics_model_parmeters(list_detailed_modules_parts=list_of_detailed_modules_parts,
                                                          material_dictionary=material_dictionary,
                                                          output_directory=output_directory,
                                                          nps=10000)

# %%
directory_path_to_serpent_output,number_of_stl_parts
# Out:
# ('/home/jshim/detailed_HCLL/serpent_input_file.serp', 574)

# %%
tally_dict = run_serpent_locally(directory_path_to_serpent_output)
# Out:
# /home/jshim/detailed_HCLL/serpent_input_file.serp
# ('File', '/home/jshim/detailed_HCLL/serpent_input_file.serp_det0.m', ' was not found.')
# Was the serpent simulation run?
# Has the _det0 file been output to the correct place?
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
